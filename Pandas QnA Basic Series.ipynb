# %% [markdown]
# # PANDAS

# %% [markdown]
# Before using pandas we need to import it. The below code helps us in doing so.

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1.  How to Read tabular data from files?

# %% [markdown]
# #### Dataset is chip orders. Located at http://bit.ly/chiporders. The files could be placed locally aswell and can work offline.
#
# If the above line works fine i.e. panda imports fine then we can use tab to see what all functions and attributes are available with pandas.
# Each time we type some attribute or function we can use "tab" to list/autocomplete the function and attribute.
#
# "read_table" file takes multiple input but the 1st argument is the location of dataset. "sep" can be used to mention how the columns are separated. By default it is \t=tab separated but we can change it to any character we want to mention the column separator. Also the function assumes the 1st row is a header.
#
# In Python a series or a dataframe starts with index 0.
#
# ##### Note: This dataset has no index and index is getting generated outmatically and this has a header as the 1st row.

# %%
chiporders = pd.read_table("http://bit.ly/chiporders", sep="\t",header=0, index_col=None) 
# Reads the file directly from the link
# we can select what all columns to choose for reading with usecols=[list of columns to read]

# %%
chiporders.head() #shows top 5 rows
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# #### Dataset Movieusers at http://bit.ly/moviusers is different dataset which has index col and it does not have header. Also note that the columns are separated by |.

# %%
movies = pd.read_table("http://bit.ly/movieusers", sep="|", header=None, index_col=0)

# %% [markdown]
# #### To mention the dataset doesn't have header we mention that in read_table method using header=none. similarly we could have left index_col and it would have been another column in dataset. But if we mention that in read_table it is marked as index.
#
# we could add the names for the columns i.e. define the header

# %%
movies.head()
# Out:
#     1  2           3      4
# 0
# 1  24  M  technician  85711
# 2  53  F       other  94043
# 3  23  M      writer  32067
# 4  24  M  technician  43537
# 5  33  F       other  15213

# %%
user_cols = ["Age", "Gender", "Occupation", "Zip Code"]
movies = pd.read_table("http://bit.ly/movieusers", sep="|", header=None, index_col=0, names=user_cols)

# %%
movies.head()
# Out:
#    Age Gender  Occupation Zip Code
# 1   24      M  technician    85711
# 2   53      F       other    94043
# 3   23      M      writer    32067
# 4   24      M  technician    43537
# 5   33      F       other    15213

# %% [markdown]
# ##### Skiprows and skipfooter tells pandas if we should be removing top or bottom rows before reading from the file to dataframe.

# %% [markdown]
# ## 2. How to select a Series from a DataFrame?

# %% [markdown]
# ##### Each column in a DataFrame is a series. A series could be not a part of DataFrame.
# We need to deal with series because we want to analyse it, derive some other series from it or manipulate the series.

# %%
ufo = pd.read_csv("http://bit.ly/uforeports") #The above command is same as read_table with sep=','

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo['City']) #type can be used to see the datatype we are dealing with
# Out:
# pandas.core.series.Series

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo['city']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# 18211                 Holyoke
# 18212                  Carson
# 18213                Pasadena
# 18214                  Austin
# 18215                El Campo
# 18216            Garden Grove
# 18217           Berthoud Pass
# 18218              Sisterdale
# 18219            Garden Grove
# 18220             Shasta Lake
# 18221                Franklin
# 18222          Albrightsville
# 18223              Greenville
# 18224                 Eufaula
# 18225             Simi Valley
# 18226           San Francisco
# 18227           San Francisco
# 18228              Kingsville
# 18229                 Chicago
# 18230             Pismo Beach
# 18231             Pismo Beach
# 18232                    Lodi
# 18233               Anchorage
# 18234                Capitola
# 18235          Fountain Hills
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: city, Length: 18241, dtype: object

# %%
ufo['City'].head() 
#returns City Column. a series. This is case sensitive. This is same as 
#ufo.City. Pandas creates an attribute for each series. But the attributes with '.' 
#are not quite useful as they are not created for all types of series. If the name is
#having a space then the attribute is not created and the series should be called using
#['']. The same is true for the column that has same name as built in function/attribute.
#for e.g. head, shape etc.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-227-58605ba1e47d> in <module>()
# ----> 1 ufo['City'].head()
#       2 #returns City Column. a series. This is case sensitive. This is same as
#       3 #ufo.City. Pandas creates an attribute for each series. But the attributes with '.'
#       4 #are not quite useful as they are not created for all types of series. If the name is
#       5 #having a space then the attribute is not created and the series should be called using
#
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'

# %%
ufo.columns #gives the column names
# Out:
# Index(['city', 'colors reported', 'shape reported', 'state', 'time'], dtype='object')

# %%
#ufo.Colors Reported is not going to work and to use it we should be using [].
ufo['Colors Reported']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          RED
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          RED
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
#           ...
# 18211       NaN
# 18212       NaN
# 18213     GREEN
# 18214       NaN
# 18215       NaN
# 18216    ORANGE
# 18217       NaN
# 18218       NaN
# 18219       NaN
# 18220      BLUE
# 18221       NaN
# 18222       NaN
# 18223       NaN
# 18224       NaN
# 18225       NaN
# 18226       NaN
# 18227       NaN
# 18228       NaN
# 18229       NaN
# 18230       NaN
# 18231       NaN
# 18232       NaN
# 18233       RED
# 18234       NaN
# 18235       NaN
# 18236       NaN
# 18237       NaN
# 18238       NaN
# 18239       RED
# 18240       NaN
# Name: Colors Reported, Length: 18241, dtype: object

# %% [markdown]
# ##### Create new series in a DF

# %% [markdown]
# ##### Addition of string/numbers can be performed element wise calling the operation on two series. e.g.

# %%
ufo.City +', '+ ufo.State
# Out:
# 0                      Ithaca, NY
# 1                 Willingboro, NJ
# 2                     Holyoke, CO
# 3                     Abilene, KS
# 4        New York Worlds Fair, NY
# 5                 Valley City, ND
# 6                 Crater Lake, CA
# 7                        Alma, MI
# 8                     Eklutna, AK
# 9                     Hubbard, OR
# 10                    Fontana, CA
# 11                   Waterloo, AL
# 12                     Belton, SC
# 13                     Keokuk, IA
# 14                  Ludington, MI
# 15                Forest Home, CA
# 16                Los Angeles, CA
# 17                  Hapeville, GA
# 18                     Oneida, TN
# 19                 Bering Sea, AK
# 20                   Nebraska, NE
# 21                            NaN
# 22                            NaN
# 23                  Owensboro, KY
# 24                 Wilderness, WV
# 25                  San Diego, CA
# 26                 Wilderness, WV
# 27                     Clovis, NM
# 28                 Los Alamos, NM
# 29               Ft. Duschene, UT
#                    ...
# 18211                 Holyoke, MA
# 18212                  Carson, CA
# 18213                Pasadena, CA
# 18214                  Austin, TX
# 18215                El Campo, TX
# 18216            Garden Grove, CA
# 18217           Berthoud Pass, CO
# 18218              Sisterdale, TX
# 18219            Garden Grove, CA
# 18220             Shasta Lake, CA
# 18221                Franklin, NH
# 18222          Albrightsville, PA
# 18223              Greenville, SC
# 18224                 Eufaula, OK
# 18225             Simi Valley, CA
# 18226           San Francisco, CA
# 18227           San Francisco, CA
# 18228              Kingsville, TX
# 18229                 Chicago, IL
# 18230             Pismo Beach, CA
# 18231             Pismo Beach, CA
# 18232                    Lodi, WI
# 18233               Anchorage, AK
# 18234                Capitola, CA
# 18235          Fountain Hills, AZ
# 18236              Grant Park, IL
# 18237             Spirit Lake, IA
# 18238             Eagle River, WI
# 18239             Eagle River, WI
# 18240                    Ybor, FL
# Length: 18241, dtype: object

# %%
#we cannot use . operation to create new fields/series in DF.

# %%
ufo.Location = ufo.City +', '+ ufo.State
# Out:
# D:\Profiles\rkumarsingh\AppData\Local\conda\conda\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
ufo["Location"] = ufo.City +', '+ ufo.State #When assigning is done for a series 
#[] notation should be used.s

# %%
ufo.Location.head(10) # head can be applied to series as well.
# Out:
# 0                  Ithaca, NY
# 1             Willingboro, NJ
# 2                 Holyoke, CO
# 3                 Abilene, KS
# 4    New York Worlds Fair, NY
# 5             Valley City, ND
# 6             Crater Lake, CA
# 7                    Alma, MI
# 8                 Eklutna, AK
# 9                 Hubbard, OR
# dtype: object

# %%
ratings = pd.read_csv('http://bit.ly/imdbratings') #Import the dataset

# %%
ratings.head() #Display the top 5 rows
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
ratings.describe() #It describes the numeric columns. i.e. finds out the statistical
#parameter for the columns. This is a function call. Action on columns.
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
ratings.shape #attribute call. Returns a tuple. Fetch the attributes exposed by DF.
# Out:
# (979, 6)

# %% [markdown]
# ##### DataType of each Column

# %%
ratings.dtypes #returns datatype of each column
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
#Functions/Actions can have optional arguments e.g.
ratings.describe(include=['object', 'int64'])
# Out:
#                                   title content_rating  genre    duration  \
# count                               979            976    979  979.000000
# unique                              975             12     16         NaN
# top     The Girl with the Dragon Tattoo              R  Drama         NaN
# freq                                  2            460    278         NaN
# mean                                NaN            NaN    NaN  120.979571
# std                                 NaN            NaN    NaN   26.218010
# min                                 NaN            NaN    NaN   64.000000
# 25%                                 NaN            NaN    NaN  102.000000
# 50%                                 NaN            NaN    NaN  117.000000
# 75%                                 NaN            NaN    NaN  134.000000
# max                                 NaN            NaN    NaN  242.000000
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# ## How to rename columns in Pandas DF

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")

# %%
ufo.head() # Returns column name along with some data.
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns #Returns column names of the DF
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %% [markdown]
# ##### Rename the column so that the space is replaced with '_'

# %%
ufo.rename(columns={'Colors Reported':'Colors_Reported', 'Shape Reported':'Shape_Reported'}, inplace=True)
#If we do not use inplace=True the output will be modified one but the actual dataframe wont be.
#If we dont want to use inplace then we should use a new variable to store the changed df.

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %% [markdown]
# ##### In case we want to change multiple columns at once using the above code is
# ##### not suggested. We can use something which is :

# %%
#Considering to change all the column name characters from upper case to lower.
ufo_cols=['city', 'colors reported', 'shape reported', 'state', 'time']
ufo.columns = ufo_cols

# %%
ufo.columns
#Still this is tideous and lengthy if there are many columns.
# Out:
# Index(['city', 'colors reported', 'shape reported', 'state', 'time'], dtype='object')

# %%
##### In case we have columns and we want to replace them or if there are no
##### column names we can still go ahead and use names=column_name_list while
##### reading the file. We should be careful if there are headers and should 
##### mentioned which row is header or there are no headers.
ufo2 = pd.read_csv("http://bit.ly/uforeports", names=ufo_cols, header=0)

# %%
ufo2.columns
# Out:
# Index(['city', 'colors reported', 'shape reported', 'state', 'time'], dtype='object')

# %%
movies.head()
# Out:
#    Age Gender  Occupation Zip Code
# 1   24      M  technician    85711
# 2   53      F       other    94043
# 3   23      M      writer    32067
# 4   24      M  technician    43537
# 5   33      F       other    15213

# %%
movies2 = pd.read_table('http://bit.ly/movieusers', sep='|', names=user_cols, header=None, index_col=0)

# %%
movies2.columns
#In the read_table we can see we need to mention the header and index_col
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Zip Code'], dtype='object')

# %%
#In case we want to replace only the spaces in the column names we can use
ufo2.columns = ufo2.columns.str.replace(' ', '_')
#This will call the string replace method for every element in the list.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-45e43e9fb578> in <module>()
#       1 #In case we want to replace only the spaces in the column names we can use
# ----> 2 ufo2.columns = ufo2.columns.str.lower.replace(' ', '_')
#       3 #This will call the string replace method for every element in the list.
#
# AttributeError: 'function' object has no attribute 'replace'

# %%
ufo2.columns
# Out:
# Index(['city', 'colors_reported', 'shape_reported', 'state', 'time'], dtype='object')

# %% [markdown]
# ##### Drop Columns using 'drop' method.

# %%
ufo2.drop(["colors_reported"], axis=1, inplace=True) 
#axis = 1 represents the columns
#axis = 0 represents the rows.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-c93218b634fb> in <module>()
# ----> 1 ufo2.drop(["colors_reported"], axis=1, inplace=True)
#
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~\AppData\Local\conda\conda\envs\fastai\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: "labels ['colors_reported'] not contained in axis"

# %%
ufo2.columns
# Out:
# Index(['city', 'shape_reported', 'state', 'time'], dtype='object')

# %% [markdown]
# ##### We can use drop method to drop rows aswell but we need to use axis = 0.
# In drop method to drop the rows we need to send the indexes of the rows

# %%
ufo2.head()
# Out:
#                    city shape_reported state             time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
### We will try to remove the 1st and 2nd row i.e. rows indexed 0 and 1
ufo2.drop([0,1], axis=0, inplace=True)

# %%
ufo2.head()
# Out:
#                    city shape_reported state             time
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00
# 5           Valley City           DISK    ND  9/15/1934 15:30
# 6           Crater Lake         CIRCLE    CA   6/15/1935 0:00

# %% [markdown]
# ##### the upper call above is basically a pointer to the upper method of string for the columns object

# %%
ufo.columns.str.upper
# Out:
# <bound method _noarg_wrapper.<locals>.wrapper of <pandas.core.strings.StringMethods object at 0x000000001AA7F320>>

# %%
ufo2.columns.str.upper
# Out:
# <bound method _noarg_wrapper.<locals>.wrapper of <pandas.core.strings.StringMethods object at 0x000000001AA7F2E8>>

# %% [markdown]
# ## How to sort the DataFrame or Series.

# %%
movies = pd.read_csv("http://bit.ly/imdbratings")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# ##### The sorting can be done for a series using df.column_name.sort_values()

# %%
#Sorting the series not the DF.
movies['title'].sort_values()
#The sorting happens by symbol 1st, then numbers and then characters
#The above statement is same as movies.title.sort_values()
#There are few optional arguments which allows if we want to do a ascending 
#or descending ordering, for rows or columns inplace or not. etc.
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# 716                         A Few Good Men
# 750                    A Fish Called Wanda
# 276                   A Fistful of Dollars
# 612                     A Hard Day's Night
# 883                  A History of Violence
# 869              A Nightmare on Elm Street
# 865                        A Perfect World
# 426                              A Prophet
#                       ...
# 207       What Ever Happened to Baby Jane?
# 562            What's Eating Gilbert Grape
# 719                When Harry Met Sally...
# 649                      Where Eagles Dare
# 33                                Whiplash
# 669                Who Framed Roger Rabbit
# 219        Who's Afraid of Virginia Woolf?
# 127                      Wild Strawberries
# 497    Willy Wonka & the Chocolate Factory
# 270                        Wings of Desire
# 483                           Withnail & I
# 920                                Witness
# 65             Witness for the Prosecution
# 970                            Wonder Boys
# 518                         Wreck-It Ralph
# 954                                  X-Men
# 248             X-Men: Days of Future Past
# 532                     X-Men: First Class
# 871                                     X2
# 695                      Y Tu Mama Tambien
# 403                             Ying xiong
# 235                                Yip Man
# 96                                 Yojimbo
# 280                     Young Frankenstein
# 535                                  Zelig
# 955                       Zero Dark Thirty
# 677                                 Zodiac
# 615                             Zombieland
# 526                                   Zulu
# 864                                  [Rec]
# Name: title, Length: 979, dtype: object

# %% [markdown]
# ##### Sorting the df by a column

# %%
movies.sort_values(['content_rating', "duration"], ascending=False)
#Sort by multiple column and make them ascending. The sort is nested if the
#multiple columns are selected for sorting
#How to do ascending on one and descending on other.
# Out:
#      star_rating                               title content_rating  \
# 86           8.4                  A Clockwork Orange              X
# 387          8.0                     Midnight Cowboy              X
# 913          7.5                            Suspiria              X
# 486          7.8                        Evil Dead II              X
# 17           8.7                       Seven Samurai        UNRATED
# 120          8.3                    The Great Escape        UNRATED
# 257          8.1                 Anatomy of a Murder        UNRATED
# 730          7.6                     West Side Story        UNRATED
# 526          7.8                                Zulu        UNRATED
# 289          8.1      All Quiet on the Western Front        UNRATED
# 262          8.1                         The Hustler        UNRATED
# 217          8.1                  Memories of Murder        UNRATED
# 802          7.6                         Tell No One        UNRATED
# 317          8.0                    Dawn of the Dead        UNRATED
# 161          8.2                          Diabolique        UNRATED
# 239          8.1       Elite Squad: The Enemy Within        UNRATED
# 582          7.8                             Sabrina        UNRATED
# 823          7.5                          Straw Dogs        UNRATED
# 687          7.7                          Spellbound        UNRATED
# 96           8.4                             Yojimbo        UNRATED
# 472          7.8        Guess Who's Coming to Dinner        UNRATED
# 757          7.6                         Funny Games        UNRATED
# 123          8.3                         The General        UNRATED
# 144          8.2               It Happened One Night        UNRATED
# 291          8.1                          The Return        UNRATED
# 523          7.8                           Repulsion        UNRATED
# 652          7.7                     This Is England        UNRATED
# 376          8.0                           King Kong        UNRATED
# 412          7.9                           Key Largo        UNRATED
# 353          8.0            Night of the Living Dead        UNRATED
# ..           ...                                 ...            ...
# 38           8.6                         Rear Window       APPROVED
# 410          7.9                    Bonnie and Clyde       APPROVED
# 563          7.8                          Goldfinger       APPROVED
# 329          8.0            In the Heat of the Night       APPROVED
# 230          8.1               Cat on a Hot Tin Roof       APPROVED
# 350          8.0                   Shadow of a Doubt       APPROVED
# 298          8.0                        The Graduate       APPROVED
# 866          7.5                    To Catch a Thief       APPROVED
# 575          7.8                   Kramer vs. Kramer       APPROVED
# 94           8.4                 Singin' in the Rain       APPROVED
# 285          8.1                    Bringing Up Baby       APPROVED
# 229          8.1                Strangers on a Train       APPROVED
# 237          8.1                           Notorious       APPROVED
# 521          7.8                       Belle de Jour       APPROVED
# 451          7.9              Miracle on 34th Street       APPROVED
# 233          8.1             The Night of the Hunter       APPROVED
# 287          8.1                     His Girl Friday       APPROVED
# 484          7.8       The Day the Earth Stood Still       APPROVED
# 58           8.5                      Paths of Glory       APPROVED
# 210          8.1                               Laura       APPROVED
# 656          7.7     Snow White and the Seven Dwarfs       APPROVED
# 844          7.5                           Pinocchio       APPROVED
# 612          7.7                  A Hard Day's Night       APPROVED
# 272          8.1                         The Killing       APPROVED
# 703          7.6                             Dracula       APPROVED
# 513          7.8      Invasion of the Body Snatchers       APPROVED
# 713          7.6                     The Jungle Book       APPROVED
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
#
#          genre  duration                                        actors_list
# 86       Crime       136  [u'Malcolm McDowell', u'Patrick Magee', u'Mich...
# 387      Drama       113  [u'Dustin Hoffman', u'Jon Voight', u'Sylvia Mi...
# 913     Horror        92  [u'Jessica Harper', u'Stefania Casini', u'Flav...
# 486     Comedy        84  [u'Bruce Campbell', u'Sarah Berry', u'Dan Hicks']
# 17       Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 120  Adventure       172  [u'Steve McQueen', u'James Garner', u'Richard ...
# 257      Crime       160  [u'James Stewart', u'Lee Remick', u'Ben Gazzara']
# 730      Crime       152  [u'Natalie Wood', u'George Chakiris', u'Richar...
# 526      Drama       138  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 289      Drama       136     [u'Lew Ayres', u'Louis Wolheim', u'John Wray']
# 262      Drama       134  [u'Paul Newman', u'Jackie Gleason', u'Piper La...
# 217      Crime       132  [u'Kang-ho Song', u'Sang-kyung Kim', u'Roe-ha ...
# 802      Crime       131  [u'Fran\xe7ois Cluzet', u'Marie-Jos\xe9e Croze...
# 317     Horror       127  [u'David Emge', u'Ken Foree', u'Scott H. Reini...
# 161     Horror       116  [u'Simone Signoret', u'V\xe9ra Clouzot', u'Pau...
# 239     Action       115  [u'Wagner Moura', u'Irandhir Santos', u'Andr\x...
# 582     Comedy       113  [u'Humphrey Bogart', u'Audrey Hepburn', u'Will...
# 823      Crime       113  [u'Dustin Hoffman', u'Susan George', u'Peter V...
# 687  Film-Noir       111  [u'Ingrid Bergman', u'Gregory Peck', u'Michael...
# 96      Action       110  [u'Toshir\xf4 Mifune', u'Eijir\xf4 T\xf4no', u...
# 472     Comedy       108  [u'Spencer Tracy', u'Sidney Poitier', u'Kathar...
# 757      Crime       108  [u'Susanne Lothar', u'Ulrich M\xfche', u'Arno ...
# 123     Action       107  [u'Buster Keaton', u'Marion Mack', u'Glen Cave...
# 144     Comedy       105  [u'Clark Gable', u'Claudette Colbert', u'Walte...
# 291      Drama       105  [u'Vladimir Garin', u'Ivan Dobronravov', u'Kon...
# 523      Drama       105  [u'Catherine Deneuve', u'Ian Hendry', u'John F...
# 652      Crime       101  [u'Thomas Turgoose', u'Stephen Graham', u'Jo H...
# 376  Adventure       100  [u'Fay Wray', u'Robert Armstrong', u'Bruce Cab...
# 412      Crime       100  [u'Humphrey Bogart', u'Edward G. Robinson', u'...
# 353     Horror        96  [u'Duane Jones', u"Judith O'Dea", u'Karl Hardm...
# ..         ...       ...                                                ...
# 38     Mystery       112  [u'James Stewart', u'Grace Kelly', u'Wendell C...
# 410  Biography       111  [u'Warren Beatty', u'Faye Dunaway', u'Michael ...
# 563     Action       110  [u'Sean Connery', u'Gert Fr\xf6be', u'Honor Bl...
# 329      Crime       109  [u'Sidney Poitier', u'Rod Steiger', u'Warren O...
# 230      Drama       108  [u'Elizabeth Taylor', u'Paul Newman', u'Burl I...
# 350   Thriller       108  [u'Teresa Wright', u'Joseph Cotten', u'Macdona...
# 298     Comedy       106  [u'Dustin Hoffman', u'Anne Bancroft', u'Kathar...
# 866    Mystery       106  [u'Cary Grant', u'Grace Kelly', u'Jessie Royce...
# 575      Drama       105  [u'Dustin Hoffman', u'Meryl Streep', u'Jane Al...
# 94      Comedy       103  [u'Gene Kelly', u"Donald O'Connor", u'Debbie R...
# 285     Comedy       102  [u'Katharine Hepburn', u'Cary Grant', u'Charle...
# 229      Crime       101  [u'Farley Granger', u'Robert Walker', u'Ruth R...
# 237      Drama       101  [u'Cary Grant', u'Ingrid Bergman', u'Claude Ra...
# 521      Drama       101  [u'Catherine Deneuve', u'Jean Sorel', u'Michel...
# 451     Comedy        96  [u'Edmund Gwenn', u"Maureen O'Hara", u'John Pa...
# 233      Crime        92  [u'Robert Mitchum', u'Shelley Winters', u'Lill...
# 287     Comedy        92  [u'Cary Grant', u'Rosalind Russell', u'Ralph B...
# 484     Sci-Fi        92  [u'Michael Rennie', u'Patricia Neal', u'Hugh M...
# 58       Drama        88  [u'Kirk Douglas', u'Ralph Meeker', u'Adolphe M...
# 210  Film-Noir        88  [u'Gene Tierney', u'Dana Andrews', u'Clifton W...
# 656  Animation        88  [u'Adriana Caselotti', u'Harry Stockwell', u'L...
# 844  Animation        88  [u'Dickie Jones', u'Christian Rub', u'Mel Blanc']
# 612     Comedy        87  [u'John Lennon', u'Paul McCartney', u'George H...
# 272      Crime        85  [u'Sterling Hayden', u'Coleen Gray', u'Vince E...
# 703     Horror        85  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 513     Horror        80  [u'Kevin McCarthy', u'Dana Wynter', u'Larry Ga...
# 713  Animation        78  [u'Phil Harris', u'Sebastian Cabot', u'Louis P...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
#
# [979 rows x 6 columns]

# %% [markdown]
# order and sort were functions which were being used to sort the series and df.

# %% [markdown]
#  ## How to filter rows from data frame

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# An arithmatic operation, comaprison etc can be executed on each element of the series and it allows to get a derived series. If its a boolean series we can use it to filter the dataframe rows.

# %%
movies[(movies.duration > 200)]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 157              G      Drama       238
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
# 476          PG-13      Drama       242
# 630          PG-13  Biography       202
# 767       APPROVED     Action       205
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 630  [u'Denzel Washington', u'Angela Bassett', u'De...
# 767  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
#we can select a specific column using the column name e.g.
movies[(movies.duration>200) & (movies.genre == "Drama")]['title']
#this does the job but it may not be best optimized way to get the genre.
# Out:
# 17          Seven Samurai
# 157    Gone with the Wind
# 476                Hamlet
# Name: title, dtype: object

# %%
#Therefore we can use loc df function
movies.loc[(movies.duration>200) & (movies.genre == "Drama"),['genre','title']]
#This is more like selecting rows and columns
#The and operation is executed with &.
#loc can be used to select specific columns
# Out:
#      genre               title
# 17   Drama       Seven Samurai
# 157  Drama  Gone with the Wind
# 476  Drama              Hamlet

# %%
movies.genre.isin(['Crime','Drama','Action']).head(3) 
#this generates a boolean for the rows
# Out:
# 0    True
# 1    True
# 2    True
# Name: genre, dtype: bool

# %%
movies[movies.genre.isin(['crime','Drama','Action'])]['genre']
# Out:
# 3      Action
# 5       Drama
# 9       Drama
# 11     Action
# 12     Action
# 13      Drama
# 16      Drama
# 17      Drama
# 19     Action
# 20     Action
# 22      Drama
# 24      Drama
# 27      Drama
# 32      Drama
# 33      Drama
# 36     Action
# 37     Action
# 41      Drama
# 43     Action
# 44     Action
# 45     Action
# 47      Drama
# 50      Drama
# 51      Drama
# 53      Drama
# 56      Drama
# 58      Drama
# 67      Drama
# 72      Drama
# 73      Drama
#         ...
# 897     Drama
# 901     Drama
# 904     Drama
# 906    Action
# 908    Action
# 910     Drama
# 914     Drama
# 916     Drama
# 917     Drama
# 918    Action
# 922     Drama
# 923     Drama
# 925     Drama
# 926     Drama
# 939     Drama
# 941     Drama
# 945     Drama
# 946     Drama
# 947     Drama
# 951     Drama
# 954    Action
# 955     Drama
# 958     Drama
# 963    Action
# 967    Action
# 968     Drama
# 970     Drama
# 972     Drama
# 973     Drama
# 976    Action
# Name: genre, Length: 414, dtype: object
